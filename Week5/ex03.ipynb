# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
file_name = "../Data/README.md"

# %%
word = sc.textFile(file_name).flatMap(lambda x : x.split(" "))
word_rdd = word.map(lambda x : (x,1))

# %%
word_rdd.take(5)
# Out:
# [('#', 1), ('Apache', 1), ('Spark', 1), ('', 1), ('Spark', 1)]

# %%
grouped_word_rdd = word_rdd.groupByKey()

# %%
grouped_word_rdd.glom().collect()
# Out:
# [[('#', <pyspark.resultiterable.ResultIterable at 0x114d93cc0>),
#   ('Apache', <pyspark.resultiterable.ResultIterable at 0x114d93da0>),
#   ('Spark', <pyspark.resultiterable.ResultIterable at 0x114d93e10>),
#   ('', <pyspark.resultiterable.ResultIterable at 0x114d93e48>),
#   ('is', <pyspark.resultiterable.ResultIterable at 0x114d93eb8>),
#   ('It', <pyspark.resultiterable.ResultIterable at 0x114d93f28>),
#   ('provides', <pyspark.resultiterable.ResultIterable at 0x114d93f60>),
#   ('high-level', <pyspark.resultiterable.ResultIterable at 0x114d93f98>),
#   ('APIs', <pyspark.resultiterable.ResultIterable at 0x114dd4048>),
#   ('in', <pyspark.resultiterable.ResultIterable at 0x114dd40b8>),
#   ('Scala,', <pyspark.resultiterable.ResultIterable at 0x114dd4128>),
#   ('Java,', <pyspark.resultiterable.ResultIterable at 0x114dd4198>),
#   ('an', <pyspark.resultiterable.ResultIterable at 0x114dd4208>),
#   ('optimized', <pyspark.resultiterable.ResultIterable at 0x114dd4278>),
#   ('engine', <pyspark.resultiterable.ResultIterable at 0x114dd42e8>),
#   ('supports', <pyspark.resultiterable.ResultIterable at 0x114dd4320>),
#   ('computation', <pyspark.resultiterable.ResultIterable at 0x114dd4358>),
#   ('analysis.', <pyspark.resultiterable.ResultIterable at 0x114dd4390>),
#   ('set', <pyspark.resultiterable.ResultIterable at 0x114dd4400>),
#   ('of', <pyspark.resultiterable.ResultIterable at 0x114dd4470>),
#   ('tools', <pyspark.resultiterable.ResultIterable at 0x114dd44e0>),
#   ('SQL', <pyspark.resultiterable.ResultIterable at 0x114dd4550>),
#   ('MLlib', <pyspark.resultiterable.ResultIterable at 0x114dd45c0>),
#   ('machine', <pyspark.resultiterable.ResultIterable at 0x114dd4630>),
#   ('learning,', <pyspark.resultiterable.ResultIterable at 0x114dd4668>),
#   ('GraphX', <pyspark.resultiterable.ResultIterable at 0x114dd46d8>),
#   ('graph', <pyspark.resultiterable.ResultIterable at 0x114dd4748>),
#   ('processing,', <pyspark.resultiterable.ResultIterable at 0x114dd4780>),
#   ('Documentation', <pyspark.resultiterable.ResultIterable at 0x114dd47b8>),
#   ('latest', <pyspark.resultiterable.ResultIterable at 0x114dd4828>),
#   ('programming', <pyspark.resultiterable.ResultIterable at 0x114dd4860>),
#   ('guide,', <pyspark.resultiterable.ResultIterable at 0x114dd48d0>),
#   ('[project', <pyspark.resultiterable.ResultIterable at 0x114dd4908>),
#   ('README', <pyspark.resultiterable.ResultIterable at 0x114dd4978>),
#   ('only', <pyspark.resultiterable.ResultIterable at 0x114dd49e8>),
#   ('basic', <pyspark.resultiterable.ResultIterable at 0x114dd4a58>),
#   ('instructions.', <pyspark.resultiterable.ResultIterable at 0x114dd4a90>),
#   ('Building', <pyspark.resultiterable.ResultIterable at 0x114dd4ac8>),
#   ('using', <pyspark.resultiterable.ResultIterable at 0x114dd4b38>),
#   ('[Apache', <pyspark.resultiterable.ResultIterable at 0x114dd4ba8>),
#   ('run:', <pyspark.resultiterable.ResultIterable at 0x114dd4c18>),
#   ('do', <pyspark.resultiterable.ResultIterable at 0x114dd4c88>),
#   ('this', <pyspark.resultiterable.ResultIterable at 0x114dd4cf8>),
#   ('downloaded', <pyspark.resultiterable.ResultIterable at 0x114dd4d30>),
#   ('more', <pyspark.resultiterable.ResultIterable at 0x114dd4da0>),
#   ('than', <pyspark.resultiterable.ResultIterable at 0x114dd4e10>),
#   ('-T', <pyspark.resultiterable.ResultIterable at 0x114dd4e80>),
#   ('Maven', <pyspark.resultiterable.ResultIterable at 0x114dd4ef0>),
#   ('3"](https://cwiki.apache.org/confluence/display/MAVEN/Parallel+builds+in+Maven+3).',
#    <pyspark.resultiterable.ResultIterable at 0x114dd4f28>),
#   ('documentation', <pyspark.resultiterable.ResultIterable at 0x114dd4f60>),
#   ('project', <pyspark.resultiterable.ResultIterable at 0x114dd4fd0>),
#   ('site,', <pyspark.resultiterable.ResultIterable at 0x114dd8080>),
#   ('at', <pyspark.resultiterable.ResultIterable at 0x114dd80f0>),
#   ('Spark"](http://spark.apache.org/docs/latest/building-spark.html).',
#    <pyspark.resultiterable.ResultIterable at 0x114dd8128>),
#   ('developing', <pyspark.resultiterable.ResultIterable at 0x114dd8160>),
#   ('IDE,', <pyspark.resultiterable.ResultIterable at 0x114dd81d0>),
#   ('Interactive', <pyspark.resultiterable.ResultIterable at 0x114dd8208>),
#   ('Shell', <pyspark.resultiterable.ResultIterable at 0x114dd8278>),
#   ('The', <pyspark.resultiterable.ResultIterable at 0x114dd82e8>),
#   ('way', <pyspark.resultiterable.ResultIterable at 0x114dd8358>),
#   ('start', <pyspark.resultiterable.ResultIterable at 0x114dd83c8>),
#   ('Try', <pyspark.resultiterable.ResultIterable at 0x114dd8438>),
#   ('following', <pyspark.resultiterable.ResultIterable at 0x114dd8470>),
#   ('1000:', <pyspark.resultiterable.ResultIterable at 0x114dd84e0>),
#   ('scala>', <pyspark.resultiterable.ResultIterable at 0x114dd8550>),
#   ('1000).count()', <pyspark.resultiterable.ResultIterable at 0x114dd8588>),
#   ('Python', <pyspark.resultiterable.ResultIterable at 0x114dd85f8>),
#   ('Alternatively,', <pyspark.resultiterable.ResultIterable at 0x114dd8630>),
#   ('use', <pyspark.resultiterable.ResultIterable at 0x114dd86a0>),
#   ('And', <pyspark.resultiterable.ResultIterable at 0x114dd8710>),
#   ('run', <pyspark.resultiterable.ResultIterable at 0x114dd8780>),
#   ('Example', <pyspark.resultiterable.ResultIterable at 0x114dd87f0>),
#   ('several', <pyspark.resultiterable.ResultIterable at 0x114dd8860>),
#   ('programs', <pyspark.resultiterable.ResultIterable at 0x114dd8898>),
#   ('them,', <pyspark.resultiterable.ResultIterable at 0x114dd8908>),
#   ('`./bin/run-example',
#    <pyspark.resultiterable.ResultIterable at 0x114dd8940>),
#   ('[params]`.', <pyspark.resultiterable.ResultIterable at 0x114dd8978>),
#   ('example:', <pyspark.resultiterable.ResultIterable at 0x114dd89b0>),
#   ('./bin/run-example',
#    <pyspark.resultiterable.ResultIterable at 0x114dd89e8>),
#   ('SparkPi', <pyspark.resultiterable.ResultIterable at 0x114dd8a58>),
#   ('variable', <pyspark.resultiterable.ResultIterable at 0x114dd8a90>),
#   ('when', <pyspark.resultiterable.ResultIterable at 0x114dd8b00>),
#   ('examples', <pyspark.resultiterable.ResultIterable at 0x114dd8b38>),
#   ('spark://', <pyspark.resultiterable.ResultIterable at 0x114dd8b70>),
#   ('URL,', <pyspark.resultiterable.ResultIterable at 0x114dd8be0>),
#   ('YARN,', <pyspark.resultiterable.ResultIterable at 0x114dd8c50>),
#   ('"local"', <pyspark.resultiterable.ResultIterable at 0x114dd8cc0>),
#   ('locally', <pyspark.resultiterable.ResultIterable at 0x114dd8d30>),
#   ('N', <pyspark.resultiterable.ResultIterable at 0x114dd8d68>),
#   ('abbreviated', <pyspark.resultiterable.ResultIterable at 0x114dd8da0>),
#   ('class', <pyspark.resultiterable.ResultIterable at 0x114dd8e10>),
#   ('name', <pyspark.resultiterable.ResultIterable at 0x114dd8e80>),
#   ('package.', <pyspark.resultiterable.ResultIterable at 0x114dd8eb8>),
#   ('instance:', <pyspark.resultiterable.ResultIterable at 0x114dd8ef0>),
#   ('print', <pyspark.resultiterable.ResultIterable at 0x114dd8f60>),
#   ('usage', <pyspark.resultiterable.ResultIterable at 0x114dd8fd0>),
#   ('help', <pyspark.resultiterable.ResultIterable at 0x114ddf080>),
#   ('no', <pyspark.resultiterable.ResultIterable at 0x114ddf0f0>),
#   ('params', <pyspark.resultiterable.ResultIterable at 0x114ddf160>),
#   ('are', <pyspark.resultiterable.ResultIterable at 0x114ddf1d0>),
#   ('Testing', <pyspark.resultiterable.ResultIterable at 0x114ddf240>),
#   ('Spark](#building-spark).',
#    <pyspark.resultiterable.ResultIterable at 0x114ddf278>),
#   ('Once', <pyspark.resultiterable.ResultIterable at 0x114ddf2e8>),
#   ('built,', <pyspark.resultiterable.ResultIterable at 0x114ddf358>),
#   ('tests', <pyspark.resultiterable.ResultIterable at 0x114ddf3c8>),
#   ('using:', <pyspark.resultiterable.ResultIterable at 0x114ddf438>),
#   ('./dev/run-tests', <pyspark.resultiterable.ResultIterable at 0x114ddf470>),
#   ('Please', <pyspark.resultiterable.ResultIterable at 0x114ddf4e0>),
#   ('guidance', <pyspark.resultiterable.ResultIterable at 0x114ddf518>),
#   ('module,', <pyspark.resultiterable.ResultIterable at 0x114ddf588>),
#   ('individual', <pyspark.resultiterable.ResultIterable at 0x114ddf5c0>),
#   ('Note', <pyspark.resultiterable.ResultIterable at 0x114ddf630>),
#   ('About', <pyspark.resultiterable.ResultIterable at 0x114ddf6a0>),
#   ('uses', <pyspark.resultiterable.ResultIterable at 0x114ddf710>),
#   ('library', <pyspark.resultiterable.ResultIterable at 0x114ddf780>),
#   ('HDFS', <pyspark.resultiterable.ResultIterable at 0x114ddf7f0>),
#   ('other', <pyspark.resultiterable.ResultIterable at 0x114ddf860>),
#   ('Hadoop-supported', <pyspark.resultiterable.ResultIterable at 0x10a9beeb8>),
#   ('storage', <pyspark.resultiterable.ResultIterable at 0x114d93be0>),
#   ('systems.', <pyspark.resultiterable.ResultIterable at 0x114d93b38>),
#   ('Because', <pyspark.resultiterable.ResultIterable at 0x114d939b0>),
#   ('have', <pyspark.resultiterable.ResultIterable at 0x114d938d0>),
#   ('changed', <pyspark.resultiterable.ResultIterable at 0x114d93710>),
#   ('different', <pyspark.resultiterable.ResultIterable at 0x114d93940>),
#   ('versions', <pyspark.resultiterable.ResultIterable at 0x114d93a20>),
#   ('Hadoop,', <pyspark.resultiterable.ResultIterable at 0x114d936d8>),
#   ('must', <pyspark.resultiterable.ResultIterable at 0x114d93908>),
#   ('against', <pyspark.resultiterable.ResultIterable at 0x114d934e0>),
#   ('version', <pyspark.resultiterable.ResultIterable at 0x114d93668>),
#   ('refer', <pyspark.resultiterable.ResultIterable at 0x114d937b8>),
#   ('particular', <pyspark.resultiterable.ResultIterable at 0x114d939e8>),
#   ('distribution', <pyspark.resultiterable.ResultIterable at 0x114d93a58>),
#   ('Hive', <pyspark.resultiterable.ResultIterable at 0x114d93438>),
#   ('Thriftserver', <pyspark.resultiterable.ResultIterable at 0x114d93588>),
#   ('distributions.', <pyspark.resultiterable.ResultIterable at 0x114d935f8>),
#   ('[Configuration', <pyspark.resultiterable.ResultIterable at 0x114d935c0>),
#   ('Guide](http://spark.apache.org/docs/latest/configuration.html)',
#    <pyspark.resultiterable.ResultIterable at 0x114cd89b0>),
#   ('online', <pyspark.resultiterable.ResultIterable at 0x114cd8da0>),
#   ('overview', <pyspark.resultiterable.ResultIterable at 0x114d6c550>),
#   ('configure', <pyspark.resultiterable.ResultIterable at 0x114d6cf98>),
#   ('Spark.', <pyspark.resultiterable.ResultIterable at 0x114d6cd30>)],
#  [('a', <pyspark.resultiterable.ResultIterable at 0x114d93cf8>),
#   ('fast', <pyspark.resultiterable.ResultIterable at 0x114d6c588>),
#   ('and', <pyspark.resultiterable.ResultIterable at 0x114d6c438>),
#   ('general', <pyspark.resultiterable.ResultIterable at 0x114d6c4e0>),
#   ('cluster', <pyspark.resultiterable.ResultIterable at 0x114d6c3c8>),
#   ('computing', <pyspark.resultiterable.ResultIterable at 0x114d6c2e8>),
#   ('system', <pyspark.resultiterable.ResultIterable at 0x114d6c780>),
#   ('for', <pyspark.resultiterable.ResultIterable at 0x114d6cda0>),
#   ('Big', <pyspark.resultiterable.ResultIterable at 0x114d6c518>),
#   ('Data.', <pyspark.resultiterable.ResultIterable at 0x114d6c400>),
#   ('Python,', <pyspark.resultiterable.ResultIterable at 0x114d54898>),
#   ('R,', <pyspark.resultiterable.ResultIterable at 0x114d54f28>),
#   ('that', <pyspark.resultiterable.ResultIterable at 0x114d54e80>),
#   ('graphs', <pyspark.resultiterable.ResultIterable at 0x114d54e48>),
#   ('data', <pyspark.resultiterable.ResultIterable at 0x114d540b8>),
#   ('also', <pyspark.resultiterable.ResultIterable at 0x114ddf8d0>),
#   ('rich', <pyspark.resultiterable.ResultIterable at 0x114ddf940>),
#   ('higher-level', <pyspark.resultiterable.ResultIterable at 0x114ddf978>),
#   ('including', <pyspark.resultiterable.ResultIterable at 0x114ddf9b0>),
#   ('DataFrames,', <pyspark.resultiterable.ResultIterable at 0x114ddf9e8>),
#   ('Streaming', <pyspark.resultiterable.ResultIterable at 0x114ddfa20>),
#   ('stream', <pyspark.resultiterable.ResultIterable at 0x114ddfa90>),
#   ('processing.', <pyspark.resultiterable.ResultIterable at 0x114ddfac8>),
#   ('<http://spark.apache.org/>',
#    <pyspark.resultiterable.ResultIterable at 0x114ddfb00>),
#   ('##', <pyspark.resultiterable.ResultIterable at 0x114ddfb70>),
#   ('Online', <pyspark.resultiterable.ResultIterable at 0x114ddfbe0>),
#   ('You', <pyspark.resultiterable.ResultIterable at 0x114ddfc50>),
#   ('can', <pyspark.resultiterable.ResultIterable at 0x114ddfcf8>),
#   ('find', <pyspark.resultiterable.ResultIterable at 0x114ddfd68>),
#   ('the', <pyspark.resultiterable.ResultIterable at 0x114ddfdd8>),
#   ('documentation,', <pyspark.resultiterable.ResultIterable at 0x114ddfe10>),
#   ('on', <pyspark.resultiterable.ResultIterable at 0x114ddfe80>),
#   ('web', <pyspark.resultiterable.ResultIterable at 0x114ddfef0>),
#   ('page](http://spark.apache.org/documentation.html)',
#    <pyspark.resultiterable.ResultIterable at 0x114ddff28>),
#   ('wiki](https://cwiki.apache.org/confluence/display/SPARK).',
#    <pyspark.resultiterable.ResultIterable at 0x114ddff60>),
#   ('This', <pyspark.resultiterable.ResultIterable at 0x114ddffd0>),
#   ('file', <pyspark.resultiterable.ResultIterable at 0x114dd6080>),
#   ('contains', <pyspark.resultiterable.ResultIterable at 0x114dd60b8>),
#   ('setup', <pyspark.resultiterable.ResultIterable at 0x114dd6128>),
#   ('built', <pyspark.resultiterable.ResultIterable at 0x114dd6198>),
#   ('Maven](http://maven.apache.org/).',
#    <pyspark.resultiterable.ResultIterable at 0x114dd61d0>),
#   ('To', <pyspark.resultiterable.ResultIterable at 0x114dd6240>),
#   ('build', <pyspark.resultiterable.ResultIterable at 0x114dd62b0>),
#   ('its', <pyspark.resultiterable.ResultIterable at 0x114dd6358>),
#   ('example', <pyspark.resultiterable.ResultIterable at 0x114dd63c8>),
#   ('programs,', <pyspark.resultiterable.ResultIterable at 0x114dd6400>),
#   ('build/mvn', <pyspark.resultiterable.ResultIterable at 0x114dd6438>),
#   ('-DskipTests', <pyspark.resultiterable.ResultIterable at 0x114dd6470>),
#   ('clean', <pyspark.resultiterable.ResultIterable at 0x114dd64e0>),
#   ('package', <pyspark.resultiterable.ResultIterable at 0x114dd6550>),
#   ('(You', <pyspark.resultiterable.ResultIterable at 0x114dd65c0>),
#   ('not', <pyspark.resultiterable.ResultIterable at 0x114dd6630>),
#   ('need', <pyspark.resultiterable.ResultIterable at 0x114dd66a0>),
#   ('to', <pyspark.resultiterable.ResultIterable at 0x114dd6710>),
#   ('if', <pyspark.resultiterable.ResultIterable at 0x114dd6780>),
#   ('you', <pyspark.resultiterable.ResultIterable at 0x114dd6828>),
#   ('pre-built', <pyspark.resultiterable.ResultIterable at 0x114dd6898>),
#   ('package.)', <pyspark.resultiterable.ResultIterable at 0x114dd68d0>),
#   ('one', <pyspark.resultiterable.ResultIterable at 0x114dd6940>),
#   ('thread', <pyspark.resultiterable.ResultIterable at 0x114dd69b0>),
#   ('by', <pyspark.resultiterable.ResultIterable at 0x114dd6a20>),
#   ('option', <pyspark.resultiterable.ResultIterable at 0x114dd6a90>),
#   ('with', <pyspark.resultiterable.ResultIterable at 0x114dd6b00>),
#   ('Maven,', <pyspark.resultiterable.ResultIterable at 0x114dd6ba8>),
#   ('see', <pyspark.resultiterable.ResultIterable at 0x114dd6c18>),
#   ('["Parallel', <pyspark.resultiterable.ResultIterable at 0x114dd6c50>),
#   ('builds', <pyspark.resultiterable.ResultIterable at 0x114dd6cc0>),
#   ('More', <pyspark.resultiterable.ResultIterable at 0x114dd6d30>),
#   ('detailed', <pyspark.resultiterable.ResultIterable at 0x114dd6d68>),
#   ('available', <pyspark.resultiterable.ResultIterable at 0x114dd6da0>),
#   ('from', <pyspark.resultiterable.ResultIterable at 0x114dd6e10>),
#   ('["Building', <pyspark.resultiterable.ResultIterable at 0x114dd6e48>),
#   ('For', <pyspark.resultiterable.ResultIterable at 0x114dd6eb8>),
#   ('[Eclipse](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-Eclipse)',
#    <pyspark.resultiterable.ResultIterable at 0x114dd6ef0>),
#   ('[IntelliJ](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-IntelliJ).',
#    <pyspark.resultiterable.ResultIterable at 0x114dd6f28>),
#   ('Scala', <pyspark.resultiterable.ResultIterable at 0x114dd6f98>),
#   ('easiest', <pyspark.resultiterable.ResultIterable at 0x114de4048>),
#   ('through', <pyspark.resultiterable.ResultIterable at 0x114de40b8>),
#   ('shell:', <pyspark.resultiterable.ResultIterable at 0x114de4128>),
#   ('./bin/spark-shell',
#    <pyspark.resultiterable.ResultIterable at 0x114de4160>),
#   ('command,', <pyspark.resultiterable.ResultIterable at 0x114de4198>),
#   ('which', <pyspark.resultiterable.ResultIterable at 0x114de4208>),
#   ('should', <pyspark.resultiterable.ResultIterable at 0x114de4278>),
#   ('return', <pyspark.resultiterable.ResultIterable at 0x114de42e8>),
#   ('sc.parallelize(1', <pyspark.resultiterable.ResultIterable at 0x114de4320>),
#   ('prefer', <pyspark.resultiterable.ResultIterable at 0x114de4390>),
#   ('./bin/pyspark', <pyspark.resultiterable.ResultIterable at 0x114de43c8>),
#   ('>>>', <pyspark.resultiterable.ResultIterable at 0x114de4438>),
#   ('sc.parallelize(range(1000)).count()',
#    <pyspark.resultiterable.ResultIterable at 0x114de4470>),
#   ('Programs', <pyspark.resultiterable.ResultIterable at 0x114de44a8>),
#   ('comes', <pyspark.resultiterable.ResultIterable at 0x114de4518>),
#   ('sample', <pyspark.resultiterable.ResultIterable at 0x114de4588>),
#   ('`examples`', <pyspark.resultiterable.ResultIterable at 0x114de45c0>),
#   ('directory.', <pyspark.resultiterable.ResultIterable at 0x114de45f8>),
#   ('<class>', <pyspark.resultiterable.ResultIterable at 0x114de4668>),
#   ('will', <pyspark.resultiterable.ResultIterable at 0x114de46d8>),
#   ('Pi', <pyspark.resultiterable.ResultIterable at 0x114de4748>),
#   ('locally.', <pyspark.resultiterable.ResultIterable at 0x114de4780>),
#   ('MASTER', <pyspark.resultiterable.ResultIterable at 0x114de47f0>),
#   ('environment', <pyspark.resultiterable.ResultIterable at 0x114de4828>),
#   ('running', <pyspark.resultiterable.ResultIterable at 0x114de4898>),
#   ('submit', <pyspark.resultiterable.ResultIterable at 0x114de4908>),
#   ('cluster.', <pyspark.resultiterable.ResultIterable at 0x114de4940>),
#   ('be', <pyspark.resultiterable.ResultIterable at 0x114de49b0>),
#   ('mesos://', <pyspark.resultiterable.ResultIterable at 0x114de49e8>),
#   ('or', <pyspark.resultiterable.ResultIterable at 0x114de4a58>),
#   ('"yarn"', <pyspark.resultiterable.ResultIterable at 0x114de4ac8>),
#   ('thread,', <pyspark.resultiterable.ResultIterable at 0x114de4b38>),
#   ('"local[N]"', <pyspark.resultiterable.ResultIterable at 0x114de4b70>),
#   ('threads.', <pyspark.resultiterable.ResultIterable at 0x114de4ba8>),
#   ('MASTER=spark://host:7077',
#    <pyspark.resultiterable.ResultIterable at 0x114de4be0>),
#   ('Many', <pyspark.resultiterable.ResultIterable at 0x114de4c50>),
#   ('given.', <pyspark.resultiterable.ResultIterable at 0x114de4cc0>),
#   ('Running', <pyspark.resultiterable.ResultIterable at 0x114de4d30>),
#   ('Tests', <pyspark.resultiterable.ResultIterable at 0x114de4da0>),
#   ('first', <pyspark.resultiterable.ResultIterable at 0x114de4e10>),
#   ('requires', <pyspark.resultiterable.ResultIterable at 0x114de4e48>),
#   ('[building', <pyspark.resultiterable.ResultIterable at 0x114de4e80>),
#   ('how', <pyspark.resultiterable.ResultIterable at 0x114de4ef0>),
#   ('[run', <pyspark.resultiterable.ResultIterable at 0x114de4f60>),
#   ('tests](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools).',
#    <pyspark.resultiterable.ResultIterable at 0x114de4f98>),
#   ('A', <pyspark.resultiterable.ResultIterable at 0x114de4fd0>),
#   ('Hadoop', <pyspark.resultiterable.ResultIterable at 0x114de9080>),
#   ('Versions', <pyspark.resultiterable.ResultIterable at 0x114de90b8>),
#   ('core', <pyspark.resultiterable.ResultIterable at 0x114de9128>),
#   ('talk', <pyspark.resultiterable.ResultIterable at 0x114de9198>),
#   ('protocols', <pyspark.resultiterable.ResultIterable at 0x114de91d0>),
#   ('same', <pyspark.resultiterable.ResultIterable at 0x114de9240>),
#   ('your', <pyspark.resultiterable.ResultIterable at 0x114de92b0>),
#   ('runs.', <pyspark.resultiterable.ResultIterable at 0x114de9320>),
#   ('["Specifying', <pyspark.resultiterable.ResultIterable at 0x114de9358>),
#   ('Version"](http://spark.apache.org/docs/latest/building-spark.html#specifying-the-hadoop-version)',
#    <pyspark.resultiterable.ResultIterable at 0x114de9390>),
#   ('building', <pyspark.resultiterable.ResultIterable at 0x114de93c8>),
#   ('Configuration', <pyspark.resultiterable.ResultIterable at 0x114de9400>)]]

# %%
word_count = grouped_word_rdd.mapValues(lambda x : sum(x))

# %%
word_count.glom().collect()
# Out:
# [[('#', 1),
#   ('Apache', 1),
#   ('Spark', 15),
#   ('', 68),
#   ('is', 6),
#   ('It', 2),
#   ('provides', 1),
#   ('high-level', 1),
#   ('APIs', 1),
#   ('in', 6),
#   ('Scala,', 1),
#   ('Java,', 1),
#   ('an', 4),
#   ('optimized', 1),
#   ('engine', 1),
#   ('supports', 2),
#   ('computation', 1),
#   ('analysis.', 1),
#   ('set', 2),
#   ('of', 5),
#   ('tools', 1),
#   ('SQL', 2),
#   ('MLlib', 1),
#   ('machine', 1),
#   ('learning,', 1),
#   ('GraphX', 1),
#   ('graph', 1),
#   ('processing,', 1),
#   ('Documentation', 1),
#   ('latest', 1),
#   ('programming', 1),
#   ('guide,', 1),
#   ('[project', 2),
#   ('README', 1),
#   ('only', 1),
#   ('basic', 1),
#   ('instructions.', 1),
#   ('Building', 1),
#   ('using', 5),
#   ('[Apache', 1),
#   ('run:', 1),
#   ('do', 2),
#   ('this', 1),
#   ('downloaded', 1),
#   ('more', 1),
#   ('than', 1),
#   ('-T', 1),
#   ('Maven', 1),
#   ('3"](https://cwiki.apache.org/confluence/display/MAVEN/Parallel+builds+in+Maven+3).',
#    1),
#   ('documentation', 3),
#   ('project', 1),
#   ('site,', 1),
#   ('at', 2),
#   ('Spark"](http://spark.apache.org/docs/latest/building-spark.html).', 1),
#   ('developing', 1),
#   ('IDE,', 1),
#   ('Interactive', 2),
#   ('Shell', 2),
#   ('The', 1),
#   ('way', 1),
#   ('start', 1),
#   ('Try', 1),
#   ('following', 2),
#   ('1000:', 2),
#   ('scala>', 1),
#   ('1000).count()', 1),
#   ('Python', 2),
#   ('Alternatively,', 1),
#   ('use', 3),
#   ('And', 1),
#   ('run', 7),
#   ('Example', 1),
#   ('several', 1),
#   ('programs', 2),
#   ('them,', 1),
#   ('`./bin/run-example', 1),
#   ('[params]`.', 1),
#   ('example:', 1),
#   ('./bin/run-example', 2),
#   ('SparkPi', 2),
#   ('variable', 1),
#   ('when', 1),
#   ('examples', 2),
#   ('spark://', 1),
#   ('URL,', 1),
#   ('YARN,', 1),
#   ('"local"', 1),
#   ('locally', 2),
#   ('N', 1),
#   ('abbreviated', 1),
#   ('class', 2),
#   ('name', 1),
#   ('package.', 1),
#   ('instance:', 1),
#   ('print', 1),
#   ('usage', 1),
#   ('help', 1),
#   ('no', 1),
#   ('params', 1),
#   ('are', 1),
#   ('Testing', 1),
#   ('Spark](#building-spark).', 1),
#   ('Once', 1),
#   ('built,', 1),
#   ('tests', 2),
#   ('using:', 1),
#   ('./dev/run-tests', 1),
#   ('Please', 3),
#   ('guidance', 2),
#   ('module,', 1),
#   ('individual', 1),
#   ('Note', 1),
#   ('About', 1),
#   ('uses', 1),
#   ('library', 1),
#   ('HDFS', 1),
#   ('other', 1),
#   ('Hadoop-supported', 1),
#   ('storage', 1),
#   ('systems.', 1),
#   ('Because', 1),
#   ('have', 1),
#   ('changed', 1),
#   ('different', 1),
#   ('versions', 1),
#   ('Hadoop,', 2),
#   ('must', 1),
#   ('against', 1),
#   ('version', 1),
#   ('refer', 2),
#   ('particular', 2),
#   ('distribution', 1),
#   ('Hive', 2),
#   ('Thriftserver', 1),
#   ('distributions.', 1),
#   ('[Configuration', 1),
#   ('Guide](http://spark.apache.org/docs/latest/configuration.html)', 1),
#   ('online', 1),
#   ('overview', 1),
#   ('configure', 1),
#   ('Spark.', 1)],
#  [('a', 8),
#   ('fast', 1),
#   ('and', 11),
#   ('general', 2),
#   ('cluster', 2),
#   ('computing', 1),
#   ('system', 1),
#   ('for', 11),
#   ('Big', 1),
#   ('Data.', 1),
#   ('Python,', 2),
#   ('R,', 1),
#   ('that', 2),
#   ('graphs', 1),
#   ('data', 1),
#   ('also', 4),
#   ('rich', 1),
#   ('higher-level', 1),
#   ('including', 3),
#   ('DataFrames,', 1),
#   ('Streaming', 1),
#   ('stream', 1),
#   ('processing.', 1),
#   ('<http://spark.apache.org/>', 1),
#   ('##', 8),
#   ('Online', 1),
#   ('You', 4),
#   ('can', 7),
#   ('find', 1),
#   ('the', 22),
#   ('documentation,', 1),
#   ('on', 5),
#   ('web', 1),
#   ('page](http://spark.apache.org/documentation.html)', 1),
#   ('wiki](https://cwiki.apache.org/confluence/display/SPARK).', 1),
#   ('This', 2),
#   ('file', 1),
#   ('contains', 1),
#   ('setup', 1),
#   ('built', 1),
#   ('Maven](http://maven.apache.org/).', 1),
#   ('To', 2),
#   ('build', 4),
#   ('its', 1),
#   ('example', 3),
#   ('programs,', 1),
#   ('build/mvn', 1),
#   ('-DskipTests', 1),
#   ('clean', 1),
#   ('package', 1),
#   ('(You', 1),
#   ('not', 1),
#   ('need', 1),
#   ('to', 14),
#   ('if', 4),
#   ('you', 4),
#   ('pre-built', 1),
#   ('package.)', 1),
#   ('one', 3),
#   ('thread', 1),
#   ('by', 1),
#   ('option', 1),
#   ('with', 4),
#   ('Maven,', 1),
#   ('see', 3),
#   ('["Parallel', 1),
#   ('builds', 1),
#   ('More', 1),
#   ('detailed', 2),
#   ('available', 1),
#   ('from', 1),
#   ('["Building', 1),
#   ('For', 3),
#   ('[Eclipse](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-Eclipse)',
#    1),
#   ('[IntelliJ](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-IntelliJ).',
#    1),
#   ('Scala', 2),
#   ('easiest', 1),
#   ('through', 1),
#   ('shell:', 2),
#   ('./bin/spark-shell', 1),
#   ('command,', 2),
#   ('which', 2),
#   ('should', 2),
#   ('return', 2),
#   ('sc.parallelize(1', 1),
#   ('prefer', 1),
#   ('./bin/pyspark', 1),
#   ('>>>', 1),
#   ('sc.parallelize(range(1000)).count()', 1),
#   ('Programs', 1),
#   ('comes', 1),
#   ('sample', 1),
#   ('`examples`', 2),
#   ('directory.', 1),
#   ('<class>', 1),
#   ('will', 1),
#   ('Pi', 1),
#   ('locally.', 1),
#   ('MASTER', 1),
#   ('environment', 1),
#   ('running', 1),
#   ('submit', 1),
#   ('cluster.', 1),
#   ('be', 2),
#   ('mesos://', 1),
#   ('or', 3),
#   ('"yarn"', 1),
#   ('thread,', 1),
#   ('"local[N]"', 1),
#   ('threads.', 1),
#   ('MASTER=spark://host:7077', 1),
#   ('Many', 1),
#   ('given.', 1),
#   ('Running', 1),
#   ('Tests', 1),
#   ('first', 1),
#   ('requires', 1),
#   ('[building', 1),
#   ('how', 2),
#   ('[run', 1),
#   ('tests](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools).',
#    1),
#   ('A', 1),
#   ('Hadoop', 3),
#   ('Versions', 1),
#   ('core', 1),
#   ('talk', 1),
#   ('protocols', 1),
#   ('same', 1),
#   ('your', 1),
#   ('runs.', 1),
#   ('["Specifying', 1),
#   ('Version"](http://spark.apache.org/docs/latest/building-spark.html#specifying-the-hadoop-version)',
#    1),
#   ('building', 2),
#   ('Configuration', 1)]]
